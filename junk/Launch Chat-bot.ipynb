# %% [markdown]
# # Устанавливаем всё необходимое

# %%
#!c1.4
# %cd /home/jupyter/work/resources
# !git clone https://github.com/ivan7022/MakeUHappyChatBot
# %cd MakeUHappyChatBot
# Out:
# fatal: destination path 'MakeUHappyChatBot' already exists and is not an empty directory.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-1-c9b3aabea686> in <module>
# ----> 1 get_ipython().system('git clone https://github.com/ivan7022/MakeUHappyChatBot')
#       2 get_ipython().run_line_magic('cd', 'MakeUHappyChatBot')
#       3 #
#
# /kernel/lib/python3.7/site-packages/ml_kernel/kernel.py in <lambda>(code)
#     255
#     256         self._script_executor = ScriptExecutor(ProcessHandler().system)
# --> 257         self.shell.system = lambda code: self._script_executor.execute("bash", code)
#     258
#     259     def _init_message_handlers(self):
#
# /kernel/lib/python3.7/site-packages/ml_kernel/script_executor.py in execute(self, lang, code)
#      33         return_code = self._system(code)
#      34         if return_code != 0:
# ---> 35             raise Exception('Process exited with code %d' % return_code)
#
# Exception: Process exited with code 128

# %%
#!c1.4
# %pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: emoji in /home/jupyter/.local/lib/python3.7/site-packages (from -r MakeUHappyChatBot/requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: google_trans_new in /home/jupyter/.local/lib/python3.7/site-packages (from -r MakeUHappyChatBot/requirements.txt (line 2)) (1.1.9)
# Collecting hnswlib
#   Downloading hnswlib-0.5.1.tar.gz (29 kB)
#     Preparing wheel metadata ... error
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3.7 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/_in_process.py prepare_metadata_for_build_wheel /tmp/tmp6kzqn5yp
#          cwd: /tmp/pip-install-j3ulbp5e/hnswlib_51c3d98a25db4689b9e21c5ce8b33aa2
#     Complete output (14 lines):
#     Traceback (most recent call last):
#       File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/_in_process.py", line 280, in <module>
#         main()
#       File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/_in_process.py", line 263, in main
#         json_out['return_val'] = hook(**hook_input['kwargs'])
#       File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/_in_process.py", line 133, in prepare_metadata_for_build_wheel
#         return hook(metadata_directory, config_settings)
#       File "/kernel/lib/python3.7/site-packages/setuptools/build_meta.py", line 161, in prepare_metadata_for_build_wheel
#         self.run_setup()
#       File "/kernel/lib/python3.7/site-packages/setuptools/build_meta.py", line 145, in run_setup
#         exec(compile(code, __file__, 'exec'), locals())
#       File "setup.py", line 5, in <module>
#         import pybind11
#     ModuleNotFoundError: No module named 'pybind11'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/03/8c/3e0e608278b740f2a78ba76ba406dbecc8b7d3ce8cfb858580f13ea04930/hnswlib-0.5.1.tar.gz#sha256=5598c0a1a6eeb577bc271cac59983c89eb4c1beb1b7e75ba50068e2dc0c038f2 (from https://pypi.org/simple/hnswlib/). Command errored out with exit status 1: /usr/bin/python3.7 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/_in_process.py prepare_metadata_for_build_wheel /tmp/tmp6kzqn5yp Check the logs for full command output.
#   Downloading hnswlib-0.5.0.tar.gz (29 kB)
#     Preparing wheel metadata ... error
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3.7 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/_in_process.py prepare_metadata_for_build_wheel /tmp/tmpp4ywvmfu
#          cwd: /tmp/pip-install-j3ulbp5e/hnswlib_e269993ed94c4880b7d19292dfa24257
#     Complete output (14 lines):
#     Traceback (most recent call last):
#       File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/_in_process.py", line 280, in <module>
#         main()
#       File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/_in_process.py", line 263, in main
#         json_out['return_val'] = hook(**hook_input['kwargs'])
#       File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/_in_process.py", line 133, in prepare_metadata_for_build_wheel
#         return hook(metadata_directory, config_settings)
#       File "/kernel/lib/python3.7/site-packages/setuptools/build_meta.py", line 161, in prepare_metadata_for_build_wheel
#         self.run_setup()
#       File "/kernel/lib/python3.7/site-packages/setuptools/build_meta.py", line 145, in run_setup
#         exec(compile(code, __file__, 'exec'), locals())
#       File "setup.py", line 5, in <module>
#         import pybind11
#     ModuleNotFoundError: No module named 'pybind11'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/fb/ff/a02bb1971d6034ff268bb1554009ac074d9d58434129c50bf136e7f39897/hnswlib-0.5.0.tar.gz#sha256=5a3a3d79442852b0587aec0c773a16a20e3a3b105efa229301878e78012b9901 (from https://pypi.org/simple/hnswlib/). Command errored out with exit status 1: /usr/bin/python3.7 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/_in_process.py prepare_metadata_for_build_wheel /tmp/tmpp4ywvmfu Check the logs for full command output.
#   Downloading hnswlib-0.4.0.tar.gz (17 kB)
# Requirement already satisfied: numpy in /kernel/lib/python3.7/site-packages (from -r MakeUHappyChatBot/requirements.txt (line 4)) (1.19.4)
# Collecting pymystem3
#   Downloading pymystem3-0.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in /kernel/lib/python3.7/site-packages (from -r MakeUHappyChatBot/requirements.txt (line 6)) (2.25.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from -r MakeUHappyChatBot/requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: tqdm in /home/jupyter/.local/lib/python3.7/site-packages (from -r MakeUHappyChatBot/requirements.txt (line 8)) (4.49.0)
# Requirement already satisfied: transformers in /home/jupyter/.local/lib/python3.7/site-packages (from -r MakeUHappyChatBot/requirements.txt (line 9)) (4.6.1)
# Collecting pybind11>=2.0
#   Downloading pybind11-2.6.2-py2.py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 4.3 MB/s
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jupyter/.local/lib/python3.7/site-packages (from requests->-r MakeUHappyChatBot/requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /kernel/lib/python3.7/site-packages (from requests->-r MakeUHappyChatBot/requirements.txt (line 6)) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /kernel/lib/python3.7/site-packages (from requests->-r MakeUHappyChatBot/requirements.txt (line 6)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /kernel/lib/python3.7/site-packages (from requests->-r MakeUHappyChatBot/requirements.txt (line 6)) (2.10)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch->-r MakeUHappyChatBot/requirements.txt (line 7)) (0.18.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/jupyter/.local/lib/python3.7/site-packages (from transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (0.10.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (0.0.43)
# Requirement already satisfied: importlib-metadata in /kernel/lib/python3.7/site-packages (from transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (4.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (2021.3.17)
# Requirement already satisfied: huggingface-hub==0.0.8 in /home/jupyter/.local/lib/python3.7/site-packages (from transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (0.0.8)
# Requirement already satisfied: packaging in /kernel/lib/python3.7/site-packages (from transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (20.9)
# Requirement already satisfied: typing-extensions>=3.6.4 in /kernel/lib/python3.7/site-packages (from importlib-metadata->transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /kernel/lib/python3.7/site-packages (from importlib-metadata->transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /kernel/lib/python3.7/site-packages (from packaging->transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (2.4.7)
# Requirement already satisfied: six in /kernel/lib/python3.7/site-packages (from sacremoses->transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->-r MakeUHappyChatBot/requirements.txt (line 9)) (1.0.1)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3.7 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-j3ulbp5e/hnswlib_5e3e5f8d6e0744efb3b23310614dbdb8/setup.py'"'"'; __file__='"'"'/tmp/pip-install-j3ulbp5e/hnswlib_5e3e5f8d6e0744efb3b23310614dbdb8/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-jmwalkhk
#        cwd: /tmp/pip-install-j3ulbp5e/hnswlib_5e3e5f8d6e0744efb3b23310614dbdb8/
#   Complete output (39 lines):
#   running bdist_wheel
#   running build
#   running build_ext
#   creating tmp
#   x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.7m -c /tmp/tmp_nos6gq7.cpp -o tmp/tmp_nos6gq7.o -std=c++14
#   x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.7m -c /tmp/tmppy06jm1l.cpp -o tmp/tmppy06jm1l.o -fvisibility=hidden
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-j3ulbp5e/hnswlib_5e3e5f8d6e0744efb3b23310614dbdb8/setup.py", line 116, in <module>
#       zip_safe=False,
#     File "/kernel/lib/python3.7/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/usr/lib/python3.7/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/usr/lib/python3.7/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/usr/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/usr/local/lib/python3.7/dist-packages/wheel/bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "/usr/lib/python3.7/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/usr/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/usr/lib/python3.7/distutils/command/build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "/usr/lib/python3.7/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/usr/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/kernel/lib/python3.7/site-packages/setuptools/command/build_ext.py", line 79, in run
#       _build_ext.run(self)
#     File "/kernel/lib/python3.7/site-packages/Cython/Distutils/old_build_ext.py", line 186, in run
#       _build_ext.build_ext.run(self)
#     File "/usr/lib/python3.7/distutils/command/build_ext.py", line 340, in run
#       self.build_extensions()
#     File "/tmp/pip-install-j3ulbp5e/hnswlib_5e3e5f8d6e0744efb3b23310614dbdb8/setup.py", line 88, in build_extensions
#       import pybind11
#   ModuleNotFoundError: No module named 'pybind11'
#   ----------------------------------------
#   ERROR: Failed building wheel for hnswlib
#   Running setup.py clean for hnswlib
# Failed to build hnswlib
# Installing collected packages: pybind11, pymystem3, hnswlib
#   WARNING: The script pybind11-config is installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#     Running setup.py install for hnswlib ... done
#   DEPRECATION: hnswlib was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.
# Successfully installed hnswlib-0.4.0 pybind11-2.6.2 pymystem3-0.2.0
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3.7 -m pip install --upgrade pip' command.

# %%
# %cd prod

# %%
#!g1.1
# !python3 __init__.py
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Chat-bot started
# Received message: как дела?
# Length of chat history id 1
# Received message: как дела?
# Length of chat history id 1
# Received message: у меня всё классно, а у тебя как?
# Length of chat history id 1
# Received message: круто!
# Length of chat history id 1
# Received message: погода просто супер!
# Length of chat history id 1
# Received message: а где ты живёшь?
# Length of chat history id 1
# ^C
# Chat-bot stopped
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-61f4007550bf> in <module>
# ----> 1 get_ipython().system('python3 __init__.py')
#       2 #
#
# /kernel/lib/python3.7/site-packages/ml_kernel/kernel.py in <lambda>(code)
#     255
#     256         self._script_executor = ScriptExecutor(ProcessHandler().system)
# --> 257         self.shell.system = lambda code: self._script_executor.execute("bash", code)
#     258
#     259     def _init_message_handlers(self):
#
# /kernel/lib/python3.7/site-packages/ml_kernel/script_executor.py in execute(self, lang, code)
#      33         return_code = self._system(code)
#      34         if return_code != 0:
# ---> 35             raise Exception('Process exited with code %d' % return_code)
#
# Exception: Process exited with code -1
